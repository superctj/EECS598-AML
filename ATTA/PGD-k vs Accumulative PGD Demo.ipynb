# %% [markdown]
# Setup Git Repo

# %%
## Clone Repo

# !git clone https://github.com/Faryab/ATTA.git
# Out:
# Cloning into 'ATTA'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 46 (delta 18), reused 39 (delta 13), pack-reused 0
# Unpacking objects: 100% (46/46), done.

# %%
# !rm -rf .*
# Out:
# rm: refusing to remove '.' or '..' directory: skipping '.'
# rm: refusing to remove '.' or '..' directory: skipping '..'

# %%
## Copy files into current working directory

import shutil
import os
    
source_dir = '/content/ATTA'
target_dir = '/content'
    
file_names = os.listdir(source_dir)
    
for file_name in file_names:
    shutil.move(os.path.join(source_dir, file_name), target_dir)

# %%
# !ls ## make sure files are there
# Out:
# adaptive_data_aug.py  data-config  pgd_attack_cifar10.py  train_atta_mnist.py
# adv_attack.py	      data-model   pgd_attack_mnist.py	  train_pgd_mnist.py
# ATTA		      LICENSE	   README.md
# cifar_dataloader.py   models	   train_atta_cifar.py

# %% [markdown]
# PGD K (m=1) with 1 iteration per epoch

# %%
# !time python train_pgd_mnist.py --accum 50 --num-steps 1 --model-dir "data-model/mnist-mat-atta-1"  --step-size 0.01 --epochs-reset 10000000000 --epsilon 0.3 --training-method "mat"
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0044, device='cuda:0')
# tensor(0.0048, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.455956
# tensor(-0.0147, device='cuda:0')
# tensor(0.0142, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.126191
# tensor(-0.0140, device='cuda:0')
# tensor(0.0137, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.310886
# tensor(-0.0141, device='cuda:0')
# tensor(0.0142, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.118881
# tensor(-0.0135, device='cuda:0')
# tensor(0.0140, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.101765
# tensor(-0.0139, device='cuda:0')
# tensor(0.0140, device='cuda:0')
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.153674
# tensor(-0.0136, device='cuda:0')
# tensor(0.0138, device='cuda:0')
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.130752
# tensor(-0.0136, device='cuda:0')
# ...

# %% [markdown]
# PGD K (m=10) with 20 iteration per epoch.
# This accumulates in the last 10 epochs.

# %%
# !time python train_pgd_mnist.py --accum 40 --num-steps 20 --model-dir "data-model/mnist-mat-atta-1"  --step-size 0.01 --epochs-reset 10000000000 --epsilon 0.3 --training-method "mat"
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0042, device='cuda:0')
# tensor(0.0041, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 2.177321
# tensor(-0.2037, device='cuda:0')
# tensor(0.2036, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 1.275530
# tensor(-0.2043, device='cuda:0')
# tensor(0.2037, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.852297
# tensor(-0.2036, device='cuda:0')
# tensor(0.2035, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.553796
# tensor(-0.2032, device='cuda:0')
# tensor(0.2037, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.560818
# tensor(-0.2043, device='cuda:0')
# tensor(0.2035, device='cuda:0')
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.440623
# tensor(-0.2043, device='cuda:0')
# tensor(0.2034, device='cuda:0')
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.443099
# tensor(-0.2041, device='cuda:0')
# ...

# %% [markdown]
# PGD K (m=10) with 1 iteration per epoch. This accumulates in the last 10 epochs.

# %%
# !time python train_pgd_mnist.py --accum 40 --num-steps 1 --model-dir "data-model/mnist-mat-atta-1"  --step-size 0.01 --epochs-reset 10000000000 --epsilon 0.3 --training-method "mat"
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0039, device='cuda:0')
# tensor(0.0039, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.261546
# tensor(-0.0141, device='cuda:0')
# tensor(0.0141, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.201962
# tensor(-0.0150, device='cuda:0')
# tensor(0.0144, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.105387
# tensor(-0.0138, device='cuda:0')
# tensor(0.0145, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.163344
# tensor(-0.0140, device='cuda:0')
# tensor(0.0142, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.116924
# tensor(-0.0137, device='cuda:0')
# tensor(0.0144, device='cuda:0')
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.142933
# tensor(-0.0137, device='cuda:0')
# tensor(0.0140, device='cuda:0')
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.044826
# tensor(-0.0146, device='cuda:0')
# ...

# %% [markdown]
# PGD K (m=1) with 20 iteration per epoch.

# %%
# !time python train_pgd_mnist.py --accum 50 --num-steps 20 --model-dir "data-model/mnist-mat-atta-1"  --step-size 0.01 --epochs-reset 10000000000 --epsilon 0.3 --training-method "mat"
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0038, device='cuda:0')
# tensor(0.0039, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 2.230486
# tensor(-0.2039, device='cuda:0')
# tensor(0.2032, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 1.403610
# tensor(-0.2037, device='cuda:0')
# tensor(0.2036, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.996314
# tensor(-0.2035, device='cuda:0')
# tensor(0.2035, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.731218
# tensor(-0.2039, device='cuda:0')
# tensor(0.2032, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.544702
# tensor(-0.2039, device='cuda:0')
# tensor(0.2033, device='cuda:0')
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.717745
# tensor(-0.2045, device='cuda:0')
# tensor(0.2038, device='cuda:0')
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.494525
# tensor(-0.2046, device='cuda:0')
# ...

# %% [markdown]
# PGD K (m=1) with 5 iteration per epoch.

# %%
# !time python train_pgd_mnist.py --accum 50 --num-steps 5 --model-dir "data-model/mnist-mat-atta-1"  --step-size 0.01 --epochs-reset 10000000000 --epsilon 0.3 --training-method "mat"
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0042, device='cuda:0')
# tensor(0.0045, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.848820
# tensor(-0.0539, device='cuda:0')
# tensor(0.0547, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.173874
# tensor(-0.0541, device='cuda:0')
# tensor(0.0539, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.255309
# tensor(-0.0538, device='cuda:0')
# tensor(0.0544, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.199022
# tensor(-0.0540, device='cuda:0')
# tensor(0.0537, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.339118
# tensor(-0.0540, device='cuda:0')
# tensor(0.0538, device='cuda:0')
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.223709
# tensor(-0.0537, device='cuda:0')
# tensor(0.0539, device='cuda:0')
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.175261
# tensor(-0.0537, device='cuda:0')
# ...

# %% [markdown]
# PGD K (m=1) with 10 iteration per epoch. This accumulates in the last 10 epochs.

# %%
# !time python train_pgd_mnist.py --accum 50 --num-steps 10 --model-dir "data-model/mnist-mat-atta-1"  --step-size 0.01 --epochs-reset 10000000000 --epsilon 0.3 --training-method "mat"
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0037, device='cuda:0')
# tensor(0.0049, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 1.178981
# tensor(-0.1038, device='cuda:0')
# tensor(0.1038, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.593393
# tensor(-0.1037, device='cuda:0')
# tensor(0.1044, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.323919
# tensor(-0.1035, device='cuda:0')
# tensor(0.1036, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.408803
# tensor(-0.1037, device='cuda:0')
# tensor(0.1045, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.266944
# tensor(-0.1041, device='cuda:0')
# tensor(0.1036, device='cuda:0')
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.325820
# tensor(-0.1039, device='cuda:0')
# tensor(0.1041, device='cuda:0')
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.204913
# tensor(-0.1042, device='cuda:0')
# ...

# %% [markdown]
# PGD K (m=1) with 15 iteration per epoch.

# %%
# !time python train_pgd_mnist.py --accum 50 --num-steps 15 --model-dir "data-model/mnist-mat-atta-1"  --step-size 0.01 --epochs-reset 10000000000 --epsilon 0.3 --training-method "mat"
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0039, device='cuda:0')
# tensor(0.0042, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 1.872364
# tensor(-0.1546, device='cuda:0')
# tensor(0.1540, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.814109
# tensor(-0.1538, device='cuda:0')
# tensor(0.1538, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.616325
# tensor(-0.1534, device='cuda:0')
# tensor(0.1539, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.437793
# tensor(-0.1536, device='cuda:0')
# tensor(0.1531, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.442320
# tensor(-0.1539, device='cuda:0')
# tensor(0.1540, device='cuda:0')
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.356258
# tensor(-0.1536, device='cuda:0')
# tensor(0.1538, device='cuda:0')
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.380205
# tensor(-0.1538, device='cuda:0')
# ...

# %% [markdown]
# PGD K (m=10) with 5 iteration per epoch. This accumulates in the last 10 epochs.

# %%
# !time python train_pgd_mnist.py --accum 40 --num-steps 5 --model-dir "data-model/mnist-mat-atta-1"  --step-size 0.01 --epochs-reset 10000000000 --epsilon 0.3 --training-method "mat"
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0039, device='cuda:0')
# tensor(0.0044, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.706800
# tensor(-0.0541, device='cuda:0')
# tensor(0.0541, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.440160
# tensor(-0.0534, device='cuda:0')
# tensor(0.0538, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.115360
# tensor(-0.0536, device='cuda:0')
# tensor(0.0537, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.267636
# tensor(-0.0537, device='cuda:0')
# tensor(0.0535, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.118306
# tensor(-0.0540, device='cuda:0')
# tensor(0.0542, device='cuda:0')
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.171315
# tensor(-0.0535, device='cuda:0')
# tensor(0.0538, device='cuda:0')
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.226626
# tensor(-0.0540, device='cuda:0')
# ...

# %% [markdown]
# PGD K (m=10) with 10 iteration per epoch. This accumulates in the last 10 epochs.

# %%
# !time python train_pgd_mnist.py --accum 40 --num-steps 10 --model-dir "data-model/mnist-mat-atta-1"  --step-size 0.01 --epochs-reset 10000000000 --epsilon 0.3 --training-method "mat"
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0043, device='cuda:0')
# tensor(0.0045, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 1.142810
# tensor(-0.1050, device='cuda:0')
# tensor(0.1038, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.477957
# tensor(-0.1034, device='cuda:0')
# tensor(0.1043, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.415577
# tensor(-0.1039, device='cuda:0')
# tensor(0.1037, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.291236
# tensor(-0.1034, device='cuda:0')
# tensor(0.1037, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.279171
# tensor(-0.1035, device='cuda:0')
# tensor(0.1035, device='cuda:0')
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.324675
# tensor(-0.1038, device='cuda:0')
# tensor(0.1039, device='cuda:0')
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.231499
# tensor(-0.1037, device='cuda:0')
# ...

# %% [markdown]
# PGD K (m=10) with 15 iteration per epoch. This accumulates in the last 10 epochs.

# %%
# !time python train_pgd_mnist.py --accum 40 --num-steps 15 --model-dir "data-model/mnist-mat-atta-1"  --step-size 0.01 --epochs-reset 10000000000 --epsilon 0.3 --training-method "mat"
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0035, device='cuda:0')
# tensor(0.0049, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 1.900215
# tensor(-0.1542, device='cuda:0')
# tensor(0.1545, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.771960
# tensor(-0.1540, device='cuda:0')
# tensor(0.1539, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.590843
# tensor(-0.1538, device='cuda:0')
# tensor(0.1538, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.297769
# tensor(-0.1538, device='cuda:0')
# tensor(0.1537, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.393997
# tensor(-0.1535, device='cuda:0')
# tensor(0.1537, device='cuda:0')
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.304903
# tensor(-0.1544, device='cuda:0')
# tensor(0.1537, device='cuda:0')
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.316691
# tensor(-0.1541, device='cuda:0')
# ...

# %%
x_pgd10 =   [   1,     5,   10,  15,   20]
y_loss_10 = [0.162, 1.01, 0.73,    , 0.67]

x_pgd1 =   [1,        5,    10,    15,    20]
y_loss_1 = [0.03, 0.018,  0.16, 0.153, 0.149]

# %%
import matplotlib.pylot as plt

plt.plot(x_pgd10, y_loss_10, label='m = 10 (10 accumulations)')
plt.plot(x_pgd1, y_loss_1, label='m = 1 (normal pgd)')
plt.xlabel("Number of Iterations per Epoch")
plt.ylabel("Total CE Loss")
plt.title('Fig 3(a) comparison.')
plt.legend()
plt.show()
