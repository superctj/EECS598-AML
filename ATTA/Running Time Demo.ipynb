# %%
## Clone Repo
# !git clone https://github.com/hzzheng93/ATTA.git
# !git clone https://github.com/KyleSuchenkai/PGD.git
# Out:
# fatal: destination path 'ATTA' already exists and is not an empty directory.
# fatal: destination path 'PGD' already exists and is not an empty directory.

# %%
#Save the result to google drive
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# # MAT-ATTA-1 on MNIST dataset

# %%
# !time python ./ATTA/train_atta_mnist.py --config-file ./ATTA/data-config/mnist-atta-1-mat.json --gpuid 0
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0045, device='cuda:0')
# tensor(0.0039, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 1.413694
# tensor(-0.0138, device='cuda:0')
# tensor(0.0142, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.899990
# tensor(-0.0140, device='cuda:0')
# tensor(0.0143, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.801372
# tensor(-0.0147, device='cuda:0')
# tensor(0.0143, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.489945
# tensor(-0.0142, device='cuda:0')
# tensor(0.0149, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.341088
# tensor(-0.0240, device='cuda:0')
# tensor(0.0242, device='cuda:0')
# ...

# %%
# !mv ./data-model/mnist-mat-atta-1/ ./ATTA/data-model/
# !time python ./ATTA/pgd_attack_mnist.py --model-dir ./ATTA/data-model/mnist-mat-atta-1/model-mnist-epoch60.pt --gpuid 0
# Out:
# pgd white-box attack
# err pgd (white-box):  tensor(10., device='cuda:0')
# err pgd (white-box):  tensor(10., device='cuda:0')
# err pgd (white-box):  tensor(17., device='cuda:0')
# err pgd (white-box):  tensor(17., device='cuda:0')
# err pgd (white-box):  tensor(12., device='cuda:0')
# err pgd (white-box):  tensor(17., device='cuda:0')
# err pgd (white-box):  tensor(13., device='cuda:0')
# err pgd (white-box):  tensor(14., device='cuda:0')
# err pgd (white-box):  tensor(10., device='cuda:0')
# err pgd (white-box):  tensor(10., device='cuda:0')
# err pgd (white-box):  tensor(20., device='cuda:0')
# err pgd (white-box):  tensor(9., device='cuda:0')
# err pgd (white-box):  tensor(16., device='cuda:0')
# err pgd (white-box):  tensor(8., device='cuda:0')
# err pgd (white-box):  tensor(14., device='cuda:0')
# err pgd (white-box):  tensor(12., device='cuda:0')
# err pgd (white-box):  tensor(12., device='cuda:0')
# err pgd (white-box):  tensor(14., device='cuda:0')
# ...

# %% [markdown]
# #MAT-PGD-1 on MNIST dataset

# %%
# !time python ./PGD/train_atta_mnist.py --config-file ./PGD/data-config/mnist-atta-1-mat.json --gpuid 0
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0043, device='cuda:0')
# tensor(0.0048, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 1.391391
# tensor(-0.0144, device='cuda:0')
# tensor(0.0144, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.776496
# tensor(-0.0139, device='cuda:0')
# tensor(0.0142, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.619172
# tensor(-0.0140, device='cuda:0')
# tensor(0.0140, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.531966
# tensor(-0.0137, device='cuda:0')
# tensor(0.0141, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.389434
# tensor(-0.0137, device='cuda:0')
# tensor(0.0144, device='cuda:0')
# ...

# %%
# !mv ./data-model/mnist-mat-atta-1/ ./PGD/data-model/
# !time python ./PGD/pgd_attack_mnist.py --model-dir ./PGD/data-model/mnist-mat-atta-1/model-mnist-epoch60.pt --gpuid 0
# Out:
# pgd white-box attack
# err pgd (white-box):  tensor(163., device='cuda:0')
# err pgd (white-box):  tensor(165., device='cuda:0')
# err pgd (white-box):  tensor(166., device='cuda:0')
# err pgd (white-box):  tensor(169., device='cuda:0')
# err pgd (white-box):  tensor(157., device='cuda:0')
# err pgd (white-box):  tensor(172., device='cuda:0')
# err pgd (white-box):  tensor(172., device='cuda:0')
# err pgd (white-box):  tensor(171., device='cuda:0')
# err pgd (white-box):  tensor(177., device='cuda:0')
# err pgd (white-box):  tensor(173., device='cuda:0')
# err pgd (white-box):  tensor(160., device='cuda:0')
# err pgd (white-box):  tensor(175., device='cuda:0')
# err pgd (white-box):  tensor(172., device='cuda:0')
# err pgd (white-box):  tensor(170., device='cuda:0')
# err pgd (white-box):  tensor(176., device='cuda:0')
# err pgd (white-box):  tensor(161., device='cuda:0')
# err pgd (white-box):  tensor(172., device='cuda:0')
# err pgd (white-box):  tensor(172., device='cuda:0')
# ...

# %% [markdown]
# # MAT-PGD-40 on MNIST dataset

# %%
# !time python ./PGD/train_atta_mnist.py --config-file ./PGD/data-config/mnist-atta-40-mat.json --gpuid 0
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([60000])
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# tensor(-0.0038, device='cuda:0')
# tensor(0.0043, device='cuda:0')
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 2.023117
# tensor(-0.3000, device='cuda:0')
# tensor(0.3000, device='cuda:0')
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 1.936422
# tensor(-0.3000, device='cuda:0')
# tensor(0.3000, device='cuda:0')
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 1.852964
# tensor(-0.3000, device='cuda:0')
# tensor(0.3000, device='cuda:0')
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 1.861671
# tensor(-0.3000, device='cuda:0')
# tensor(0.3000, device='cuda:0')
# ...
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.826636
# tensor(-0.3000, device='cuda:0')
# tensor(0.3000, device='cuda:0')
# ...

# %%
# !mv ./data-model/mnist-mat-atta-40/ ./PGD/data-model/
# !time python ./PGD/pgd_attack_mnist.py --model-dir ./PGD/data-model/mnist-mat-atta-40/model-mnist-epoch60.pt --gpuid 0

# %% [markdown]
# # MAT-ATTA-40 on MNIST dataset

# %%
# !time python ./ATTA/train_atta_mnist.py --config-file ./ATTA/data-config/mnist-atta-40-mat.json --gpuid 0

# %%
# !mv ./data-model/mnist-mat-atta-40/ ./ATTA/data-model/
# !time python ./ATTA/pgd_attack_mnist.py --model-dir ./ATTA/data-model/mnist-mat-atta-40/model-mnist-epoch60.pt --gpuid 0
